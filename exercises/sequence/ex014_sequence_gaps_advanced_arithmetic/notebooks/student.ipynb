# %% [markdown]
# # Advanced Arithmetic Operators
#
# ## Goal
# Practise using the `**` operator to find squares, cubes, square roots, and powers of numbers.
#
# ## How to work
# - Find the `# YOUR CODE HERE` comment in each exercise cell.
# - Delete the comment and write the missing line(s) of code in its place.
# - From the repository root, run:
#   ```
#   uv run pytest -q exercises/sequence/ex014_sequence_gaps_advanced_arithmetic/tests/test_ex014_sequence_gaps_advanced_arithmetic.py
#   ```
#
#   > 💡 **Stuck?** Use the [Arithmetic Cheatsheet](../../additional-resources/ARITHMETIC_CHEATSHEET.md) to remind yourself what each operator does.

# %% [markdown]
# ## Exercise 1 — Square a number
#
# In Python, you can square a number using the `**` operator like this: `number ** 2`.
#
# The program below will print the square of 8. Fill in the missing line so it works correctly.
#
# **Expected output:**
# ```
# The square of 8 is 64
# ```

# %%
number = 8
# YOUR CODE HERE — calculate the square of number and store it in result
result = number ** 2
print(f"The square of {number} is {result}")
# Out:
# The square of 8 is 64

# %% [markdown]
# ## Exercise 2 — Cube a number
#
# Cubing a number means raising it to the power of 3. Use the `**` operator with `3`.
#
# The program below will print the cube of 6. Fill in the missing line.
#
# **Expected output:**
# ```
# The cube of 6 is 216
# ```

# %%
number = 6
# YOUR CODE HERE — calculate the cube of number and store it in result
result = number ** 3
print(f"The cube of {number} is {result}")
# Out:
# The cube of 6 is 216

# %% [markdown]
# ## Exercise 3 — Square root with input
#
# This time the program asks the user for a number using `input()`. Notice how the input is stored in a variable first (`number_input`), then converted to an integer in a separate step (`number_int = int(number_input)`). This makes each step clear.
#
# Fill in the missing line to calculate the square root of `number_int`.
#
# **Expected output:**
# ```
# Enter a number: [⌘️: 144]
# The square root of 144 is 12.0
# ```

# %%
import math

number_input = input("Enter a number: ")
number_int = int(number_input)
# YOUR CODE HERE — calculate the square root of number_int and store it in result
result = math.sqrt(number_int)
print(f"The square root of {number_input} is {result}")
# Out:
# The square root of 144 is 12.0

# %% [markdown]
# ## Exercise 4 — Power with input
#
# Now the input values are read as text (strings). You need to convert them to integers before doing the calculation — just like in Exercise 3.
#
# Store each input in a separate variable (e.g. `base_input`), then convert them in separate steps (e.g. `base_int = int(base_input)`), then calculate the power.
#
# **Expected output:**
# ```
# Enter the base: [⌘️: 2]
# Enter the exponent: [⌘️: 10]
# 2 to the power of 10 is 1024
# ```

# %%
base_input = int(input("Enter the base: "))
exponent_input = int(input("Enter the exponent: "))
# YOUR CODE HERE — convert base_input and exponent_input to integers,
# then calculate the power and store it in result
result = base_input ** exponent_input
print(f"{base_input} to the power of {exponent_input} is {result}")
# Out:
# 2 to the power of 10 is 1024

# %% [markdown]
# ## Exercise 5 — Area of a square with input
#
# The side length is read as a string. Convert it to a number, then calculate the area using `side_float ** 2`.
#
# Remember: the side length could be a decimal, so use `float()` instead of `int()`. Store the input first (e.g. `side_input`), then convert it separately (e.g. `side_float = float(side_input)`).
#
# **Expected output:**
# ```
# Enter the side length: [⌘️: 9]
# A square with side 9 has area 81
# ```

# %%
side_input = int(input("Enter the side length: "))
# YOUR CODE HERE — convert side_input to a float (use side_float),
# then calculate the area (side_float squared) and store it in area
area = side_input ** 2
print(f"A square with side {side_input} has area {area}")
# Out:
# A square with side 9 has area 81

# %% [markdown]
# ## Exercise 6 — Area of a rectangle
#
# Building on exercise 5, write a program that asks the user for the width and length of a rectangle, then calculates and prints the area.
#
# Remember to cast each input to `float` before using it in the calculation, just like you did in exercise 5.
#
# Hint: you will need two input variables (e.g. `width_input`, `length_input`) and two float variables (e.g. `width_float`, `length_float`).
#
# **Expected output:**
# ```
# Enter the width: [⌘️: 5]
# Enter the length: [⌘️: 3]
# The area of the rectangle is 15.0
# ```

# %%
width_input = int(input("Enter the width: "))
length_input = int(input("Enter the length: "))
# YOUR CODE HERE — cast width_input to width_float
# YOUR CODE HERE — cast length_input to length_float
# YOUR CODE HERE — calculate the area and store it in area
area = width_input * length_input
print(f"The area of the rectangle is {float(area)}")
# Out:
# The area of the rectangle is 15.0

# %% [markdown]
# ## Exercise 7 — Volume of a cube
#
# The volume of a cube is side length raised to the power of 3 (`side ** 3`).
#
# Write a program that asks the user for the side length, calculates the volume, and prints the result.
#
# **Expected output:**
# ```
# Enter the side length: [⌘️: 4]
# The volume of the cube is 64.0
# ```

# %%
side_input = input("Enter the side length: ")
# YOUR CODE HERE — cast side_input to side_float
# YOUR CODE HERE — calculate the volume (side_float cubed)
volume = float(side_input) ** 3
print(f"The volume of the cube is {volume}")
# Out:
# The volume of the cube is 64.0

# %% [markdown]
# ## Exercise 8 — Square root
#
# Write a program that asks the user for a whole number, calculates its square root, and prints the result.
#
# Remember to cast the input to `int` before calculating. Use `** 0.5` to find the square root.
#
# **Expected output:**
# ```
# Enter a whole number: [⌘️: 144]
# The square root of 144 is 12.0
# ```

# %%
# YOUR CODE HERE — ask for a whole number using input() (store in number_input)
number_input = int(input("Enter a number: "))
# YOUR CODE HERE — cast number_input to int (store in number_int)
# YOUR CODE HERE — calculate the square root
result = math.sqrt(number_input)
print(f"The square root of {number_input} is {result}")
# Out:
# The square root of 144 is 12.0

# %% [markdown]
# ## Exercise 9 — Area of a circle
#
# The area of a circle is π × r². In Python you can write this as `pi * radius ** 2`.
#
# Write a program that defines a constant `pi = 3.14159`, asks the user for the radius, calculates the area, and prints it.
#
# **Expected output:**
# ```
# Enter the radius: [⌘️: 5]
# The area of the circle is 78.53975
# ```

# %%
pi = 3.14159
# YOUR CODE HERE — ask for the radius using input(), cast to float
number = float(input())
# YOUR CODE HERE — calculate the area (pi times radius squared)
area = pi * number ** 2
print(f"The area of the circle is {area}")
# Out:
# The area of the circle is 78.53975

# %% [markdown]
# ## Exercise 10 — Power calculator
#
# Write a complete program that asks the user for a base and an exponent (both whole numbers), calculates the power, and prints the result.
#
# You will need to cast both inputs to `int` before calculating.
#
# **Expected output:**
# ```
# Enter the base: [⌘️: 2]
# Enter the exponent: [⌘️: 10]
# 2 to the power of 10 is 1024
# ```

# %%
# YOUR CODE HERE — ask for the base and exponent using input()
base_input = int(input())
exponent_input = int(input())
# YOUR CODE HERE — cast both to int
# YOUR CODE HERE — calculate the power
result = base_input ** exponent_input
print(f"{base_input} to the power of {exponent_input} is {result}")
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/workspaces/python-exercises-sequence/.venv/lib/python3.12/site-packages/traitlets/traitlets.py", line 651, in get
#     value = obj._trait_values[self.name]
#             ~~~~~~~~~~~~~~~~~^^^^^^^^^^^
# KeyError: '_control_lock'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/workspaces/python-exercises-sequence/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/workspaces/python-exercises-sequence/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 347, in dispatch_control
#     async with self._control_lock:
#                ^^^^^^^^^^^^^^^^^^
#   File "/workspaces/python-exercises-sequence/.venv/lib/python3.12/site-packages/traitlets/traitlets.py", line 706, in __get__
# ...

# %%
# Self-check scratch cell (not graded)
# You can run small experiments here.

# %%
import os

os.environ["PYTUTOR_ACTIVE_VARIANT"] = "student"
from exercise_runtime_support.student_checker import run_notebook_checks

# Pass the canonical exercise_key here; do not pass a notebook path.
run_notebook_checks('ex014_sequence_gaps_advanced_arithmetic')
# Out:
# +-------------+------------------------+----------+------------------------------------------+
# | Exercise    | Check                  | Status   | Error                                    |
# +=============+========================+==========+==========================================+
# | Exercise 1  | Square a number        | 🟢 OK    |                                          |
# +-------------+------------------------+----------+------------------------------------------+
# | Exercise 2  | Cube a number          | 🟢 OK    |                                          |
# +-------------+------------------------+----------+------------------------------------------+
# | Exercise 3  | Square root            | 🟢 OK    |                                          |
# +-------------+------------------------+----------+------------------------------------------+
# | Exercise 4  | Power of a number      | 🟢 OK    |                                          |
# ...
